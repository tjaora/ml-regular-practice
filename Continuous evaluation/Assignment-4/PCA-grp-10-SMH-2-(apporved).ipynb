# %%
#importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as nd
import seaborn as sns
# %matplotlib inline

# %%
#importing data
df = pd.read_csv("/content/Student Mental health1.csv")
display(df)
# Out:
#                Timestamp Choose your gender  Age What is your course?  \
# 0         8/7/2020 12:02             Female   18          Engineering
# 1         8/7/2020 12:04               Male   21    Islamic education
# 2         8/7/2020 12:05               Male   19                  BIT
# 3         8/7/2020 12:06             Female   22                 Laws
# 4         8/7/2020 12:13               Male   23         Mathemathics
# ..                   ...                ...  ...                  ...
# 96   13/07/2020 19:56:49             Female   21                  BCS
# 97   13/07/2020 21:21:42               Male   18          Engineering
# 98   13/07/2020 21:22:56             Female   19             Nursing
# 99   13/07/2020 21:23:57             Female   23     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male   20   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df.keys()
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             0
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Timestamp                                       object
# Choose your gender                              object
# Age                                              int64
# What is your course?                            object
# Your current year of Study                      object
# What is your CGPA?                              object
# Marital status                                  object
# Do you have Depression?                         object
# Do you have Anxiety?                            object
# Do you have Panic attack?                       object
# Did you seek any specialist for a treatment?    object
# dtype: object

# %% [markdown]
# **Drop the Timestamp column**

# %%
df.drop("Timestamp", axis=1, inplace=True)
#df.drop("Did you seek any specialist for a treatment?", axis=1, inplace=True)
display(df)
# Out:
#     Choose your gender  Age What is your course? Your current year of Study  \
# 0               Female   18          Engineering                     year 1
# 1                 Male   21    Islamic education                     year 2
# 2                 Male   19                  BIT                     Year 1
# 3               Female   22                 Laws                     year 3
# 4                 Male   23         Mathemathics                     year 4
# ..                 ...  ...                  ...                        ...
# 96              Female   21                  BCS                     year 1
# 97                Male   18          Engineering                     Year 2
# 98              Female   19             Nursing                      Year 3
# 99              Female   23     Pendidikan Islam                     year 4
# 100               Male   20   Biomedical science                     Year 2
#
# ...

# %% [markdown]
# **Convert the Integers to Floats**

# %%
df['Age'] = df['Age'].astype(float)

# %% [markdown]
# **Convert object to floats**

# %%
#1
#from numpy import asarray
#from sklearn.preprocessing import OrdinalEncoder
#X = nd.reshape(['Male', 'Female'], (-1, 1))
#OrdinalEncoder().fit_transform(X)

#2
#df['What is your course?'] = pd.to_numeric(df['What is your course?'], errors='coerce')
#df = df.replace(nd.nan, 0, regex=True)


#3
#df = df.astype({'Choose your gender':'float','What is your course?':'float'})

#4
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Choose your gender"] = le.fit_transform(df["Choose your gender"])
df["What is your course?"] = le.fit_transform(df["What is your course?"])
df["Your current year of Study"] = le.fit_transform(df["Your current year of Study"])
df["What is your CGPA?"] = le.fit_transform(df["What is your CGPA?"])
df["Marital status"] = le.fit_transform(df["Marital status"])
df["Do you have Depression?"] = le.fit_transform(df["Do you have Depression?"])
df["Do you have Anxiety?"] = le.fit_transform(df["Do you have Anxiety?"])
df["Do you have Panic attack?"] = le.fit_transform(df["Do you have Panic attack?"])
df["Did you seek any specialist for a treatment?"] = le.fit_transform(df["Did you seek any specialist for a treatment?"])

print(df)
print(df.dtypes)
# Out:
#      Choose your gender   Age  What is your course?  \
# 0                     0  18.0                    17
# 1                     1  21.0                    25
# 2                     1  19.0                     4
# 3                     0  22.0                    33
# 4                     1  23.0                    37
# ..                  ...   ...                   ...
# 96                    0  21.0                     2
# 97                    1  18.0                    17
# 98                    0  19.0                    38
# 99                    0  23.0                    39
# 100                   1  20.0                     7
#
#      Your current year of Study  What is your CGPA?  Marital status  \
# 0                             3                   3               0
# 1                             4                   3               0
# 2                             0                   3               0
# ...

# %%
df['Choose your gender'] = df['Choose your gender'].astype(float)
df['What is your course?'] = df['What is your course?'].astype(float)
df['Your current year of Study'] = df['Your current year of Study'].astype(float)
df['What is your CGPA?'] = df['What is your CGPA?'].astype(float)
df['Marital status'] = df['Marital status'].astype(float)
df['Do you have Depression?'] = df['Do you have Depression?'].astype(float)
df['Do you have Anxiety?'] = df['Do you have Anxiety?'].astype(float)
df['Do you have Panic attack?'] = df['Do you have Panic attack?'].astype(float)
df['Did you seek any specialist for a treatment?'] = df['Did you seek any specialist for a treatment?'].astype(float)
display(df.dtypes)
display(df)
# Out:
# Choose your gender                              float64
# Age                                             float64
# What is your course?                            float64
# Your current year of Study                      float64
# What is your CGPA?                              float64
# Marital status                                  float64
# Do you have Depression?                         float64
# Do you have Anxiety?                            float64
# Do you have Panic attack?                       float64
# Did you seek any specialist for a treatment?    float64
# dtype: object
#      Choose your gender   Age  What is your course?  \
# 0                   0.0  18.0                  17.0
# 1                   1.0  21.0                  25.0
# 2                   1.0  19.0                   4.0
# 3                   0.0  22.0                  33.0
# 4                   1.0  23.0                  37.0
# ..                  ...   ...                   ...
# ...

# %%
cov_matrix = nd.cov(df.T)
display(cov_matrix)
# Out:
# array([[ 1.93069307e-01, -1.38613861e-02, -4.95445545e-01,
#         -1.06534653e-01, -6.46534653e-02, -1.11881188e-02,
#         -3.00990099e-02,  1.24752475e-02, -4.95049505e-03,
#         -5.44554455e-03],
#        [-1.38613861e-02,  6.19227723e+00, -2.84089109e+00,
#          7.36930693e-01,  8.06930693e-02,  9.76237624e-02,
#         -8.01980198e-02, -1.05049505e-01,  7.00990099e-02,
#          2.91089109e-02],
#        [-4.95445545e-01, -2.84089109e+00,  1.96236436e+02,
#          2.37772277e+00,  1.73277228e+00,  7.00495050e-01,
#          6.29207921e-01, -2.30198020e-01,  7.40396040e-01,
#         -2.93564356e-01],
#        [-1.06534653e-01,  7.36930693e-01,  2.37772277e+00,
#          2.01326733e+00,  1.87326733e-01, -9.40594059e-03,
#         -4.49504950e-02, -8.62376238e-02, -9.75247525e-02,
#         -4.22772277e-02],
#        [-6.46534653e-02,  8.06930693e-02,  1.73277228e+00,
#          1.87326733e-01,  9.06732673e-01,  1.40594059e-02,
# ...

# %%
eigenvalues, eigenvectors = nd.linalg.eig(cov_matrix)
display(eigenvalues)
# Out:
# array([1.96332358e+02, 6.29776521e+00, 1.88628390e+00, 8.84246311e-01,
#        3.59602864e-01, 2.10298756e-01, 1.83198855e-01, 1.50663912e-01,
#        6.10581316e-02, 4.38307176e-02])

# %%
print("Eigenvectors:")
print(eigenvectors)
# Out:
# Eigenvectors:
# [[ 2.53467660e-03  6.59481691e-03 -5.96239727e-02  6.55868240e-02
#   -1.39060667e-01  5.36242184e-01  5.84151173e-01  5.79503380e-01
#    8.72354397e-02  2.30890333e-02]
#  [ 1.48838855e-02 -9.83263705e-01 -1.78121778e-01 -1.72560762e-03
#   -8.75417514e-03  1.74346380e-02 -2.23349748e-02 -5.41623753e-03
#    1.81782698e-02 -1.17121067e-03]
#  [-9.99751997e-01 -1.21665311e-02 -1.54890929e-02  7.42417464e-03
#   -5.09452256e-03  3.89008856e-03 -2.13433201e-03 -7.75107983e-04
#    5.39966914e-04  2.52082686e-03]
#  [-1.21846762e-02 -1.77354121e-01  9.67604622e-01  1.35734498e-01
#    8.12080005e-02  4.18416913e-02  7.12198160e-02 -4.95230114e-03
#   -3.00075502e-03  1.62244289e-02]
#  [-8.87127820e-03 -2.46737347e-02  1.41933154e-01 -9.76271500e-01
#   -1.12859503e-01 -3.99647343e-02  3.04537821e-02  1.01458816e-01
#    2.20881435e-02 -4.21754765e-03]
#  [-3.56455767e-03 -1.65786021e-02 -2.40939607e-02 -2.76253245e-02
# ...

# %% [markdown]
# **PCA**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df) 
scaled_data = scaler.transform(df)
display(scaled_data)
# Out:
# array([[-0.58878406, -1.0156588 , -0.00426188, ..., -0.71236415,
#          1.43548113, -0.25131234],
#        [ 1.69841555,  0.19593418,  0.56967067, ...,  1.40377642,
#         -0.69663055, -0.25131234],
#        [ 1.69841555, -0.61179447, -0.93690226, ...,  1.40377642,
#          1.43548113, -0.25131234],
#        ...,
#        [-0.58878406, -0.61179447,  1.50231105, ..., -0.71236415,
#          1.43548113, -0.25131234],
#        [-0.58878406,  1.00366283,  1.57405262, ..., -0.71236415,
#         -0.69663055, -0.25131234],
#        [ 1.69841555, -0.20793015, -0.72167755, ..., -0.71236415,
#         -0.69663055, -0.25131234]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scaled_data)
print(scaled_data.shape)
print(x_pca.shape)
# Out:
# (101, 10)
# (101, 2)

# %%
pca.components_
# Out:
# array([[-0.11705839,  0.00998172,  0.10994864, -0.11327506,  0.09786618,
#          0.53546516,  0.55689293,  0.24473495,  0.35747767,  0.40885426],
#        [ 0.44969334, -0.29795148, -0.35237349, -0.6083892 , -0.39146624,
#         -0.09132801,  0.00705599,  0.19125642,  0.03062326,  0.12467202]])

# %% [markdown]
# **Plotting 2-dimentions**

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Choose your gender'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Age'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['What is your course?'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Your current year of Study'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['What is your CGPA?'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Marital status'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Do you have Depression?'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Do you have Anxiety?'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['Do you have Panic attack?'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Scond principal component')
# Out:
# Text(0, 0.5, 'Scond principal component')

# %%
#df_comp = pd.DataFrame(pca.components_,columns=df['Choose your gender'])
#plt.figure(figsize=(12,6))
#sns.heatmap(df_comp,cmap='plasma')
